# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1["Customer Lifetime Value"] = file1["Customer Lifetime Value"].str.rstrip('%').astype(float)

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
file2 = pd.read_csv('file2.csv')

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2["Customer Lifetime Value"] = file2["Customer Lifetime Value"].str.rstrip('%').astype(float)

# %%
file3 = pd.read_csv('file3.csv')

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# ## Show the DataFrame's shape.

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %% [markdown]
# ## Standardize header names.

# %%
file1.columns = file1.columns.str.lower()
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
file2.columns = file2.columns.str.lower()
file2
# Out:
#     customer          st gender education  customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
file3.columns = file3.columns.str.lower()
file3
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %% [markdown]
# ## Rearrange the columns in the dataframe as needed

# %%
# renaming columns
file3 = file3.rename(columns={'state':'st'})

# %%
file3
# Out:
#      customer          st  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
file2= file2[file1.columns]

# %%
file2
# Out:
#     customer          st gender education  customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
file3= file3[file1.columns]

# %%
file3
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %% [markdown]
# ## Concatenate the three dataframes

# %%
concatfiles = pd.concat([file1,file2,file3 ])   
concatfiles
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
concatfiles.columns = concatfiles.columns.str.lower()
concatfiles
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# ## Which columns are numerical?

# %%
concatfiles.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
# Income, Monthly premium auto and Total claim amount are numerical

# %% [markdown]
# ## Which columns are categorical?

# %%
# Customer, st, gender, education, customerlifetime value, income, number of open complaints, policy type and vehicle class are categorical.

# %% [markdown]
# ## Perform the data cleaning operations mentioned so far in class

# %% [markdown]
# Delete the column education and the number of open complaints from the dataframe.

# %%
concatfiles = concatfiles.drop('education', axis=1)

# %%
concatfiles
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
concatfiles = concatfiles.drop('number of open complaints', axis=1)

# %%
concatfiles
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
concatfiles['customer lifetime value'] = concatfiles['customer lifetime value'].div(100).round(2)

# %%
concatfiles
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                  6979.54      0.0
# 2     AI49188      Nevada      F                 12887.43  48767.0
# 3     WW63253  California      M                  7645.86      0.0
# 4     GA49547  Washington      M                  5363.08  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                   234.06  71941.0
# 7066  PK87824  California      F                    30.97  21604.0
# 7067  TD14365  California      M                    81.64      0.0
# 7068  UP19263  California      M                    75.24  21941.0
# 7069  Y167826  California      M                    26.12      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# Check for duplicate rows in the data and remove if any.

# %%
concatfiles.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
concatfiles.duplicated().sum()
# Out:
# 2939

# %%
concatfiles.drop_duplicates()
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                  6979.54      0.0
# 2     AI49188      Nevada      F                 12887.43  48767.0
# 3     WW63253  California      M                  7645.86      0.0
# 4     GA49547  Washington      M                  5363.08  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                   234.06  71941.0
# 7066  PK87824  California      F                    30.97  21604.0
# 7067  TD14365  California      M                    81.64      0.0
# 7068  UP19263  California      M                    75.24  21941.0
# 7069  Y167826  California      M                    26.12      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# Filter out the data for customers who have an income of 0 or less

# %%
concatfiles[concatfiles['income'] <= 0]
# Out:
#      customer          st gender  customer lifetime value  income  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F                  6979.54     0.0
# 3     WW63253  California      M                  7645.86     0.0
# 7     CF85061     Arizona      M                  7216.10     0.0
# 10    SX51350  California      M                  4738.99     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F                    56.78     0.0
# 7061  RX91025  California      M                   198.72     0.0
# 7062  AC13887  California      M                    46.29     0.0
# 7067  TD14365  California      M                    81.64     0.0
# 7069  Y167826  California      M                    26.12     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
